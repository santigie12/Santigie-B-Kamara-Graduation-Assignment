# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("covid-data.csv")

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  24/02/2020          5.0        5.0
# 1           AFG      Asia  Afghanistan  25/02/2020          5.0        0.0
# 2           AFG      Asia  Afghanistan  26/02/2020          5.0        0.0
# 3           AFG      Asia  Afghanistan  27/02/2020          5.0        0.0
# 4           AFG      Asia  Afghanistan  28/02/2020          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 122630      ZWE    Africa     Zimbabwe  06/10/2021     131434.0      229.0
# 122631      ZWE    Africa     Zimbabwe  07/10/2021     131523.0       89.0
# 122632      ZWE    Africa     Zimbabwe  08/10/2021     131705.0      182.0
# 122633      ZWE    Africa     Zimbabwe  09/10/2021     131762.0       57.0
# 122634      ZWE    Africa     Zimbabwe  10/10/2021     131796.0       34.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 122630             135.571        4630.0         3.0                2.000
# 122631             100.429        4631.0         1.0                1.143
# 122632              96.714        4634.0         3.0                1.429
# 122633              95.429        4636.0         2.0                1.571
# 122634              95.286        4637.0         1.0                1.429
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 122630  ...             1.6          30.7                  36.791
# 122631  ...             1.6          30.7                  36.791
# 122632  ...             1.6          30.7                  36.791
# 122633  ...             1.6          30.7                  36.791
# 122634  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 122630                         1.7            61.49                    0.571
# 122631                         1.7            61.49                    0.571
# 122632                         1.7            61.49                    0.571
# 122633                         1.7            61.49                    0.571
# 122634                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 122630                                   NaN                          NaN
# 122631                                   NaN                          NaN
# 122632                                   NaN                          NaN
# 122633                                   NaN                          NaN
# 122634                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 122630               NaN                                      NaN
# 122631               NaN                                      NaN
# 122632               NaN                                      NaN
# 122633               NaN                                      NaN
# 122634               NaN                                      NaN
#
# [122635 rows x 65 columns]

# %%
### Feeling all the missing values----->

df.loc[(df.new_cases_smoothed.isnull()),'new_cases_smoothed']=80
df.loc[(df.continent.isnull()),'continent']=50
df.loc[(df.total_cases.isnull()),'total_cases']=90
df.loc[(df.excess_mortality_cumulative_absolute.isnull()),'excess_mortality_cumulative_absolute']=50
df.loc[(df.excess_mortality_cumulative.isnull()),'excess_mortality_cumulative']=50
df.loc[(df.excess_mortality.isnull()),'excess_mortality']=50
df.loc[(df.excess_mortality_cumulative_per_million.isnull()),'excess_mortality_cumulative_per_million']=50
df.loc[(df.human_development_index.isnull()),'human_development_index']=50
df.loc[(df.female_smokers.isnull()),'female_smokers']=50
#df=df
df = df.fillna({'total_deaths': df['total_deaths'].min()})
df = df.fillna({'new_deaths': df['new_deaths'].mean()})
df = df.fillna({'new_deaths_smoothed': df['new_deaths_smoothed'].mean()})
df = df.fillna({'male_smokers': df['male_smokers'].mean()})

# %%
###   After data cleaning
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  24/02/2020          5.0        5.0
# 1           AFG      Asia  Afghanistan  25/02/2020          5.0        0.0
# 2           AFG      Asia  Afghanistan  26/02/2020          5.0        0.0
# 3           AFG      Asia  Afghanistan  27/02/2020          5.0        0.0
# 4           AFG      Asia  Afghanistan  28/02/2020          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 122630      ZWE    Africa     Zimbabwe  06/10/2021     131434.0      229.0
# 122631      ZWE    Africa     Zimbabwe  07/10/2021     131523.0       89.0
# 122632      ZWE    Africa     Zimbabwe  08/10/2021     131705.0      182.0
# 122633      ZWE    Africa     Zimbabwe  09/10/2021     131762.0       57.0
# 122634      ZWE    Africa     Zimbabwe  10/10/2021     131796.0       34.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                   80.000           1.0  144.668216           132.021672
# 1                   80.000           1.0  144.668216           132.021672
# 2                   80.000           1.0  144.668216           132.021672
# 3                   80.000           1.0  144.668216           132.021672
# 4                   80.000           1.0  144.668216           132.021672
# ...                    ...           ...         ...                  ...
# 122630             135.571        4630.0    3.000000             2.000000
# 122631             100.429        4631.0    1.000000             1.143000
# 122632              96.714        4634.0    3.000000             1.429000
# 122633              95.429        4636.0    2.000000             1.571000
# 122634              95.286        4637.0    1.000000             1.429000
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...            50.0     32.740154                  37.746
# 1       ...            50.0     32.740154                  37.746
# 2       ...            50.0     32.740154                  37.746
# 3       ...            50.0     32.740154                  37.746
# 4       ...            50.0     32.740154                  37.746
# ...     ...             ...           ...                     ...
# 122630  ...             1.6     30.700000                  36.791
# 122631  ...             1.6     30.700000                  36.791
# 122632  ...             1.6     30.700000                  36.791
# 122633  ...             1.6     30.700000                  36.791
# 122634  ...             1.6     30.700000                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 122630                         1.7            61.49                    0.571
# 122631                         1.7            61.49                    0.571
# 122632                         1.7            61.49                    0.571
# 122633                         1.7            61.49                    0.571
# 122634                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                       50.0                         50.0
# 1                                       50.0                         50.0
# 2                                       50.0                         50.0
# 3                                       50.0                         50.0
# 4                                       50.0                         50.0
# ...                                      ...                          ...
# 122630                                  50.0                         50.0
# 122631                                  50.0                         50.0
# 122632                                  50.0                         50.0
# 122633                                  50.0                         50.0
# 122634                                  50.0                         50.0
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                   50.0                                     50.0
# 1                   50.0                                     50.0
# 2                   50.0                                     50.0
# 3                   50.0                                     50.0
# 4                   50.0                                     50.0
# ...                  ...                                      ...
# 122630              50.0                                     50.0
# 122631              50.0                                     50.0
# 122632              50.0                                     50.0
# 122633              50.0                                     50.0
# 122634              50.0                                     50.0
#
# [122635 rows x 65 columns]

# %%
df.isnull().sum()
# Out:
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
#                                           ..
# human_development_index                    0
# excess_mortality_cumulative_absolute       0
# excess_mortality_cumulative                0
# excess_mortality                           0
# excess_mortality_cumulative_per_million    0
# Length: 65, dtype: int64

# %%
df[df.eq("Sierra Leone").any(1)].isnull().sum().any()
# Out:
# True

# %%
df[df.eq("Sierra Leone").any(1)].tail()
# Out:
#       iso_code continent      location        date  total_cases  new_cases  \
# 98415      SLE    Africa  Sierra Leone  06/10/2021       6396.0        0.0
# 98416      SLE    Africa  Sierra Leone  07/10/2021       6396.0        0.0
# 98417      SLE    Africa  Sierra Leone  08/10/2021       6396.0        0.0
# 98418      SLE    Africa  Sierra Leone  09/10/2021       6396.0        0.0
# 98419      SLE    Africa  Sierra Leone  10/10/2021       6396.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 98415               0.429         121.0         0.0                  0.0  ...
# 98416               0.286         121.0         0.0                  0.0  ...
# 98417               0.286         121.0         0.0                  0.0  ...
# 98418               0.286         121.0         0.0                  0.0  ...
# 98419               0.000         121.0         0.0                  0.0  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 98415             8.8          41.3                  19.275
# 98416             8.8          41.3                  19.275
# 98417             8.8          41.3                  19.275
# 98418             8.8          41.3                  19.275
# 98419             8.8          41.3                  19.275
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 98415                         NaN             54.7                    0.452
# 98416                         NaN             54.7                    0.452
# 98417                         NaN             54.7                    0.452
# 98418                         NaN             54.7                    0.452
# 98419                         NaN             54.7                    0.452
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 98415                                  50.0                         50.0
# 98416                                  50.0                         50.0
# 98417                                  50.0                         50.0
# 98418                                  50.0                         50.0
# 98419                                  50.0                         50.0
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 98415              50.0                                     50.0
# 98416              50.0                                     50.0
# 98417              50.0                                     50.0
# 98418              50.0                                     50.0
# 98419              50.0                                     50.0
#
# [5 rows x 65 columns]

# %%
df[df.eq("Sierra Leone").any(1)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 559 entries, 97861 to 98419
# Data columns (total 65 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   iso_code                                 559 non-null    object
#  1   continent                                559 non-null    object
#  2   location                                 559 non-null    object
#  3   date                                     559 non-null    object
#  4   total_cases                              559 non-null    float64
#  5   new_cases                                559 non-null    float64
#  6   new_cases_smoothed                       559 non-null    float64
#  7   total_deaths                             559 non-null    float64
#  8   new_deaths                               559 non-null    float64
#  9   new_deaths_smoothed                      559 non-null    float64
#  10  total_cases_per_million                  559 non-null    float64
#  11  new_cases_per_million                    559 non-null    float64
#  12  new_cases_smoothed_per_million           554 non-null    float64
#  13  total_deaths_per_million                 536 non-null    float64
#  14  new_deaths_per_million                   536 non-null    float64
#  15  new_deaths_smoothed_per_million          554 non-null    float64
#  16  reproduction_rate                        527 non-null    float64
#  17  icu_patients                             0 non-null      float64
#  18  icu_patients_per_million                 0 non-null      float64
#  19  hosp_patients                            0 non-null      float64
#  20  hosp_patients_per_million                0 non-null      float64
#  21  weekly_icu_admissions                    0 non-null      float64
#  22  weekly_icu_admissions_per_million        0 non-null      float64
#  23  weekly_hosp_admissions                   0 non-null      float64
#  24  weekly_hosp_admissions_per_million       0 non-null      float64
#  25  new_tests                                0 non-null      float64
#  26  total_tests                              0 non-null      float64
#  27  total_tests_per_thousand                 0 non-null      float64
#  28  new_tests_per_thousand                   0 non-null      float64
#  29  new_tests_smoothed                       0 non-null      float64
#  30  new_tests_smoothed_per_thousand          0 non-null      float64
#  31  positive_rate                            0 non-null      float64
#  32  tests_per_case                           0 non-null      float64
#  33  tests_units                              0 non-null      object
#  34  total_vaccinations                       21 non-null     float64
#  35  people_vaccinated                        22 non-null     float64
#  36  people_fully_vaccinated                  17 non-null     float64
#  37  total_boosters                           0 non-null      float64
#  38  new_vaccinations                         2 non-null      float64
#  39  new_vaccinations_smoothed                199 non-null    float64
#  40  total_vaccinations_per_hundred           21 non-null     float64
#  41  people_vaccinated_per_hundred            22 non-null     float64
#  42  people_fully_vaccinated_per_hundred      17 non-null     float64
#  43  total_boosters_per_hundred               0 non-null      float64
#  44  new_vaccinations_smoothed_per_million    199 non-null    float64
#  45  stringency_index                         553 non-null    float64
#  46  population                               559 non-null    float64
#  47  population_density                       559 non-null    float64
#  48  median_age                               559 non-null    float64
#  49  aged_65_older                            559 non-null    float64
#  50  aged_70_older                            559 non-null    float64
#  51  gdp_per_capita                           559 non-null    float64
#  52  extreme_poverty                          559 non-null    float64
#  53  cardiovasc_death_rate                    559 non-null    float64
#  54  diabetes_prevalence                      559 non-null    float64
#  55  female_smokers                           559 non-null    float64
#  56  male_smokers                             559 non-null    float64
#  57  handwashing_facilities                   559 non-null    float64
#  58  hospital_beds_per_thousand               0 non-null      float64
#  59  life_expectancy                          559 non-null    float64
#  60  human_development_index                  559 non-null    float64
#  61  excess_mortality_cumulative_absolute     559 non-null    float64
#  62  excess_mortality_cumulative              559 non-null    float64
#  63  excess_mortality                         559 non-null    float64
#  64  excess_mortality_cumulative_per_million  559 non-null    float64
# dtypes: float64(60), object(5)
# memory usage: 288.2+ KB

# %%
df[df.eq("Sierra Leone").any(1)].head()
# Out:
#       iso_code continent      location        date  total_cases  new_cases  \
# 97861      SLE    Africa  Sierra Leone  31/03/2020          1.0        1.0
# 97862      SLE    Africa  Sierra Leone  01/04/2020          2.0        1.0
# 97863      SLE    Africa  Sierra Leone  02/04/2020          2.0        0.0
# 97864      SLE    Africa  Sierra Leone  03/04/2020          2.0        0.0
# 97865      SLE    Africa  Sierra Leone  04/04/2020          4.0        2.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 97861                80.0           1.0  144.668216           132.021672  ...
# 97862                80.0           1.0  144.668216           132.021672  ...
# 97863                80.0           1.0  144.668216           132.021672  ...
# 97864                80.0           1.0  144.668216           132.021672  ...
# 97865                80.0           1.0  144.668216           132.021672  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 97861             8.8          41.3                  19.275
# 97862             8.8          41.3                  19.275
# 97863             8.8          41.3                  19.275
# 97864             8.8          41.3                  19.275
# 97865             8.8          41.3                  19.275
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 97861                         NaN             54.7                    0.452
# 97862                         NaN             54.7                    0.452
# 97863                         NaN             54.7                    0.452
# 97864                         NaN             54.7                    0.452
# 97865                         NaN             54.7                    0.452
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 97861                                  50.0                         50.0
# 97862                                  50.0                         50.0
# 97863                                  50.0                         50.0
# 97864                                  50.0                         50.0
# 97865                                  50.0                         50.0
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 97861              50.0                                     50.0
# 97862              50.0                                     50.0
# 97863              50.0                                     50.0
# 97864              50.0                                     50.0
# 97865              50.0                                     50.0
#
# [5 rows x 65 columns]

# %%
df.drop(['excess_mortality'],axis=1,inplace=True)

# %%
df.drop(['female_smokers'],axis=1,inplace=True)

# %%
df.drop(['excess_mortality_cumulative_per_million'],axis=1,inplace=True)

# %%
df.drop(['excess_mortality_cumulative'],axis=1,inplace=True)

# %%
#df.drop(['human_development_index'],axis=1,inplace=True)

# %%
df.drop(['new_cases_smoothed'],axis=1,inplace=True)

# %%
df.drop(['hospital_beds_per_thousand'],axis=1,inplace=True)

# %%
df[df.eq("Sierra Leone").any(1)]
# Out:
#       iso_code continent      location        date  total_cases  new_cases  \
# 97861      SLE    Africa  Sierra Leone  31/03/2020          1.0        1.0
# 97862      SLE    Africa  Sierra Leone  01/04/2020          2.0        1.0
# 97863      SLE    Africa  Sierra Leone  02/04/2020          2.0        0.0
# 97864      SLE    Africa  Sierra Leone  03/04/2020          2.0        0.0
# 97865      SLE    Africa  Sierra Leone  04/04/2020          4.0        2.0
# ...        ...       ...           ...         ...          ...        ...
# 98415      SLE    Africa  Sierra Leone  06/10/2021       6396.0        0.0
# 98416      SLE    Africa  Sierra Leone  07/10/2021       6396.0        0.0
# 98417      SLE    Africa  Sierra Leone  08/10/2021       6396.0        0.0
# 98418      SLE    Africa  Sierra Leone  09/10/2021       6396.0        0.0
# 98419      SLE    Africa  Sierra Leone  10/10/2021       6396.0        0.0
#
#        total_deaths  new_deaths  new_deaths_smoothed  total_cases_per_million  \
# 97861           1.0  144.668216           132.021672                    0.123
# 97862           1.0  144.668216           132.021672                    0.246
# 97863           1.0  144.668216           132.021672                    0.246
# 97864           1.0  144.668216           132.021672                    0.246
# 97865           1.0  144.668216           132.021672                    0.491
# ...             ...         ...                  ...                      ...
# 98415         121.0    0.000000             0.000000                  785.620
# 98416         121.0    0.000000             0.000000                  785.620
# 98417         121.0    0.000000             0.000000                  785.620
# 98418         121.0    0.000000             0.000000                  785.620
# 98419         121.0    0.000000             0.000000                  785.620
#
#        ...  aged_70_older  gdp_per_capita  extreme_poverty  \
# 97861  ...          1.285          1390.3             52.2
# 97862  ...          1.285          1390.3             52.2
# 97863  ...          1.285          1390.3             52.2
# 97864  ...          1.285          1390.3             52.2
# 97865  ...          1.285          1390.3             52.2
# ...    ...            ...             ...              ...
# 98415  ...          1.285          1390.3             52.2
# 98416  ...          1.285          1390.3             52.2
# 98417  ...          1.285          1390.3             52.2
# 98418  ...          1.285          1390.3             52.2
# 98419  ...          1.285          1390.3             52.2
#
#        cardiovasc_death_rate  diabetes_prevalence  male_smokers  \
# 97861                325.721                 2.42          41.3
# 97862                325.721                 2.42          41.3
# 97863                325.721                 2.42          41.3
# 97864                325.721                 2.42          41.3
# 97865                325.721                 2.42          41.3
# ...                      ...                  ...           ...
# 98415                325.721                 2.42          41.3
# 98416                325.721                 2.42          41.3
# 98417                325.721                 2.42          41.3
# 98418                325.721                 2.42          41.3
# 98419                325.721                 2.42          41.3
#
#        handwashing_facilities  life_expectancy  human_development_index  \
# 97861                  19.275             54.7                    0.452
# 97862                  19.275             54.7                    0.452
# 97863                  19.275             54.7                    0.452
# 97864                  19.275             54.7                    0.452
# 97865                  19.275             54.7                    0.452
# ...                       ...              ...                      ...
# 98415                  19.275             54.7                    0.452
# 98416                  19.275             54.7                    0.452
# 98417                  19.275             54.7                    0.452
# 98418                  19.275             54.7                    0.452
# 98419                  19.275             54.7                    0.452
#
#        excess_mortality_cumulative_absolute
# 97861                                  50.0
# 97862                                  50.0
# 97863                                  50.0
# 97864                                  50.0
# 97865                                  50.0
# ...                                     ...
# 98415                                  50.0
# 98416                                  50.0
# 98417                                  50.0
# 98418                                  50.0
# 98419                                  50.0
#
# [559 rows x 59 columns]

# %%
df[df.eq("Sierra Leone").any(1)].shape
# Out:
# (559, 58)

# %%
df[df.eq("Sierra Leone").any(1)].describe()
# Out:
#        total_cases   new_cases  total_deaths  new_deaths  new_deaths_smoothed  \
# count   559.000000  559.000000    536.000000  536.000000           554.000000
# mean   3213.239714   11.441860     78.399254    0.225746             0.218460
# std    1890.778672   18.714123     24.882173    0.677660             0.421416
# min       1.000000    0.000000      1.000000    0.000000             0.000000
# 25%    1957.500000    1.000000     71.000000    0.000000             0.000000
# 50%    2673.000000    5.000000     77.000000    0.000000             0.000000
# 75%    4121.000000   14.500000     79.000000    0.000000             0.286000
# max    6396.000000  192.000000    121.000000    7.000000             2.429000
#
#        total_cases_per_million  new_cases_per_million  \
# count               559.000000             559.000000
# mean                394.681787               1.405386
# std                 232.244058               2.298634
# min                   0.123000               0.000000
# 25%                 240.439500               0.123000
# 50%                 328.324000               0.614000
# 75%                 506.182000               1.781000
# max                 785.620000              23.583000
#
#        new_cases_smoothed_per_million  total_deaths_per_million  \
# count                      554.000000                536.000000
# mean                         1.417736                  9.629804
# std                          1.889798                  3.056211
# min                          0.000000                  0.123000
# 25%                          0.298000                  8.721000
# 50%                          0.675500                  9.458000
# 75%                          1.755000                  9.704000
# max                         10.914000                 14.862000
#
#        new_deaths_per_million  ...  aged_65_older  aged_70_older  \
# count              536.000000  ...   5.590000e+02   5.590000e+02
# mean                 0.027748  ...   2.538000e+00   1.285000e+00
# std                  0.083256  ...   9.778713e-15   1.333461e-15
# min                  0.000000  ...   2.538000e+00   1.285000e+00
# 25%                  0.000000  ...   2.538000e+00   1.285000e+00
# 50%                  0.000000  ...   2.538000e+00   1.285000e+00
# 75%                  0.000000  ...   2.538000e+00   1.285000e+00
# max                  0.860000  ...   2.538000e+00   1.285000e+00
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# count    5.590000e+02     5.590000e+02           5.590000e+02
# mean     1.390300e+03     5.220000e+01           3.257210e+02
# std      9.558248e-12     4.836018e-13           1.194781e-12
# min      1.390300e+03     5.220000e+01           3.257210e+02
# 25%      1.390300e+03     5.220000e+01           3.257210e+02
# 50%      1.390300e+03     5.220000e+01           3.257210e+02
# 75%      1.390300e+03     5.220000e+01           3.257210e+02
# max      1.390300e+03     5.220000e+01           3.257210e+02
#
#        diabetes_prevalence  male_smokers  handwashing_facilities  \
# count         5.590000e+02  5.590000e+02            5.590000e+02
# mean          2.420000e+00  4.130000e+01            1.927500e+01
# std           4.000383e-15  4.195957e-13            1.991302e-13
# min           2.420000e+00  4.130000e+01            1.927500e+01
# 25%           2.420000e+00  4.130000e+01            1.927500e+01
# 50%           2.420000e+00  4.130000e+01            1.927500e+01
# 75%           2.420000e+00  4.130000e+01            1.927500e+01
# max           2.420000e+00  4.130000e+01            1.927500e+01
#
#        life_expectancy  excess_mortality_cumulative_absolute
# count     5.590000e+02                                   0.0
# mean      5.470000e+01                                   NaN
# std       4.978254e-13                                   NaN
# min       5.470000e+01                                   NaN
# 25%       5.470000e+01                                   NaN
# 50%       5.470000e+01                                   NaN
# 75%       5.470000e+01                                   NaN
# max       5.470000e+01                                   NaN
#
# [8 rows x 53 columns]

# %%
df[df.eq("Sierra Leone").any(1)].groupby(['total_cases'], as_index=False).size()
# Out:
#      total_cases  size
# 0            1.0     1
# 1            2.0     3
# 2            4.0     1
# 3            6.0     3
# 4            7.0     2
# ..           ...   ...
# 432       6391.0     1
# 433       6392.0     3
# 434       6393.0     9
# 435       6394.0     3
# 436       6396.0     8
#
# [437 rows x 2 columns]

# %%
df[df.eq("Sierra Leone").any(1)].groupby(['total_deaths'], as_index=False).size()
# Out:
#     total_deaths  size
# 0            1.0     1
# 1            2.0     2
# 2            4.0     4
# 3            7.0     2
# 4            8.0     2
# ..           ...   ...
# 73         117.0     1
# 74         118.0     4
# 75         119.0     2
# 76         120.0    10
# 77         121.0    64
#
# [78 rows x 2 columns]

# %%
df[df.eq("Sierra Leone").any(1)].groupby(['new_deaths'], as_index=False).size()
# Out:
#    new_deaths  size
# 0         0.0   458
# 1         1.0    52
# 2         2.0    16
# 3         3.0     8
# 4         6.0     1
# 5         7.0     1

# %%
df[df.eq("Sierra Leone").any(1)].groupby(['life_expectancy'], as_index=False).size()
# Out:
#    life_expectancy  size
# 0             54.7   559

# %%
df[df.eq("Sierra Leone").any(1)].groupby(['population'], as_index=False).size()
# Out:
#    population  size
# 0   8141343.0   559

# %%
df[df.eq("Sierra Leone").any(1)].groupby(['total_deaths', 'total_cases', 'new_deaths', 'population','life_expectancy'],
                                         as_index=False).size().value_counts()
# Out:
# total_deaths  total_cases  new_deaths  population  life_expectancy  size
# 1.0           1.0          144.668216  8141343.0   54.7             1       1
# 79.0          3889.0       0.000000    8141343.0   54.7             1       1
#               3938.0       0.000000    8141343.0   54.7             1       1
#               3937.0       0.000000    8141343.0   54.7             2       1
#               3934.0       0.000000    8141343.0   54.7             1       1
#                                                                            ..
# 71.0          2041.0       0.000000    8141343.0   54.7             2       1
#               2035.0       0.000000    8141343.0   54.7             1       1
#               2029.0       0.000000    8141343.0   54.7             1       1
#               2028.0       1.000000    8141343.0   54.7             1       1
# 121.0         6396.0       0.000000    8141343.0   54.7             8       1
# Length: 446, dtype: int64

# %%
df[df.eq("Sierra Leone").any(1)].groupby(['total_deaths', 'total_cases', 'new_deaths', 'life_expectancy', 'population'],
                                         as_index=False).size()
# Out:
#      total_deaths  total_cases  new_deaths  life_expectancy  population  size
# 0             1.0         64.0         1.0             54.7   8141343.0     1
# 1             2.0         82.0         0.0             54.7   8141343.0     1
# 2             2.0         82.0         1.0             54.7   8141343.0     1
# 3             4.0         93.0         0.0             54.7   8141343.0     1
# 4             4.0         93.0         2.0             54.7   8141343.0     1
# ..            ...          ...         ...              ...         ...   ...
# 425         121.0       6391.0         0.0             54.7   8141343.0     1
# 426         121.0       6392.0         0.0             54.7   8141343.0     3
# 427         121.0       6393.0         0.0             54.7   8141343.0     9
# 428         121.0       6394.0         0.0             54.7   8141343.0     3
# 429         121.0       6396.0         0.0             54.7   8141343.0     8
#
# [430 rows x 6 columns]

# %%
import seaborn as sns
df[df.eq("Sierra Leone").any(1),sns.countplot(x='total_deaths', hue='total_cases', data=df)]
